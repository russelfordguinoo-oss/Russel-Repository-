# %% [markdown]
# <a href="https://colab.research.google.com/github/russelfordguinoo-oss/Russel-Repository-/blob/main/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/russelfordguinoo-oss/Russel-Repository-/blob/main/work/notebooks/w03_data_contract.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
## Unit of Analysis

One row represents the daily performance of one content page for one client on one report date.

**Table used:**
- fact_content_daily_performance

**Time window:**
- March 1, 2026 to March 31, 2026

**Prediction target (label):**
- gsc_clicks

**Excluded:**
- June 2026, because it is the final month and should be treated as the test period to avoid data leakage.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
SELECT
    COUNT(*) AS available_rows
FROM fact_content_daily_performance
WHERE
    strftime(report_date, '%Y-%m') = '2026-03'
    AND gsc_data_available IS TRUE;
# Out:
#   File "/tmp/ipykernel_696/1872044275.py", line 2
#     COUNT(*) AS available_rows
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
## Data Limits

This dataset only contains historical observations and cannot explain why content performs well or poorly.

The analysis is limited to March 2026, so it may not represent other time periods.

Rows without Google Search Console data are excluded from analyses requiring GSC metrics.

June 2026 is excluded because it is reserved as the final test period to avoid data leakage.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
