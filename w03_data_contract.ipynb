# %% [markdown]
# <a href="https://colab.research.google.com/github/russelfordguinoo-oss/Russel-Repository-/blob/main/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/russelfordguinoo-oss/Russel-Repository-/blob/main/work/notebooks/w03_data_contract.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
Unit of analysis:
One row represents one content page for one client on one report date.

Table:
fact_content_daily_performance

Time window:
March 2026

Prediction (label):
gsc_clicks

Excluded:
AI traffic columns because they are not used in this analysis.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
Features
- gsc_impressions
- gsc_avg_position
- ga4_sessions
- sessions_organic
- scroll_events

Label
- gsc_clicks

Context
- report_date
- client_hash_id
- content_hash_id

Excluded
- ai_chatgpt
- ai_claude
- ai_gemini
- ai_copilot
Reason:
These AI traffic columns are outside the scope of this analysis

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %% [markdown]
# Query 1 (grain)
#
# No duplicate rows found

# %% [markdown]
# Query 2 (count)
# Rows:
# 9,841,378
#
# First date:
# 2026-03-01
#
# Last date:
# 2026-03-31

# %% [markdown]
# Query 3 (availability)
# Rows with gsc_data_available IS TRUE
#
# 3,611,061

# %% [markdown]
# SELECT
#     report_date,
#     content_hash_id,
#     gsc_impressions,
#     gsc_avg_position,
#     ga4_sessions,
#     sessions_organic,
#     scroll_events,
#     gsc_clicks
# FROM fact_content_daily_performance
# WHERE strftime(report_date,'%Y-%m')='2026-03'
# AND gsc_data_available IS TRUE
# LIMIT 10;

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
Limitations

• This analysis only uses March 2026.
• Rows without GSC data are excluded.
• Daily performance may not represent long-term trends.
• AI traffic data is not included.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
